# %%
from pandas.io.html import read_html
page = 'https://dashboard.kerala.gov.in/hotspots.php'

wikitables = read_html(page,  attrs={"class":"table table-bordered table-striped table-hover table-sm sortable"})

print ("Extracted {num} wikitables".format(num=len(wikitables)))
wikitables[0]
# Out:
# Extracted 1 wikitables
#      Sl. No.  District LSGs needing special  attention  \
# 0          1  Palakkad                     Akathethara
# 1          2  Palakkad                       Alanallur
# 2          3  Palakkad                     Ambalappara
# 3          4  Palakkad                        Anakkara
# 4          5  Palakkad         Chittoor-Thathamangalam
# ..       ...       ...                             ...
# 117      118  Kottayam                        Kangazha
# 118      119  Kottayam                       Koruthodu
# 119      120  Kottayam                 Thrikkodithanam
# 120      121   Wayanad             Sulthan Bathery (M)
# 121      122    Idukki                          Kumali
#
#                               Containment Zones (Ward)
# 0                                                 2, 3
# 1                                            1, 14, 20
# 2                                                7, 20
# 3                                                2, 13
# ...
